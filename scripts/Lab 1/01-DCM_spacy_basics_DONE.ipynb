# %% [markdown]
# # SPACY BASICS
#
# In this lab we will learn to use the spacy.io API to annotate text. Many of the concepts seen in this lab are explained in detailed in the spacy course:
#
# https://spacy.io/usage/spacy-101
#
# Here you can configure the kind of spacy setup (language, annotators, etc.) that you may require for installation:
#
# https://spacy.io/usage

# %%
# Install Spacy and learn about Token and Sentence objects

# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Collecting spacy
#   Downloading spacy-3.2.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 5.4 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 32.1 MB/s
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 34.1 MB/s
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
#      |████████████████████████████████| 628 kB 34.7 MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 8.0 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: catalogue, typer, srsly, pydantic, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed catalogue-2.0.6 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 spacy-3.2.1 spacy-legacy-3.0.8 spacy-loggers-1.0.1 srsly-2.4.2 thinc-8.0.13 typer-0.4.0

# %% [markdown]
# # ASSIGNMENT 1
#
# Install the language modules of your choice.
#
# Read the documentation in https://spacy.io/usage and choose the language modules (according to your interests) that you would like to install.
#   + TODO: Install the language module(s).
#   + TODO: Try different language module versions for one language and compare the results obtained.

# %%
# TODO install other language modules of your choice following the https://spacy.io/usage
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 5.3 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.19.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Loading the language modules
#
# The nlp object is a language model instance. You can assume that, throughout this tutorial, nlp refers to the language model loaded by the language package or packages of your choice. In the following steps we will use spacy to process a string and a text file.

# %%
import spacy
#TODO load the installed language module
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Washington University, which is located in Missouri, is named after George Washington.")
print(doc)
# Out:
# Washington University, which is located in Missouri, is named after George Washington.

# %% [markdown]
# # ASSIGNMENT 2
#
# When you call nlp on a string, spaCy first tokenizes the text and creates a document object. In this exercise, you’ll learn more about the Doc, as well as its views Token and Span.
#
# + TODO: print the tokens in the Doc object. You should get something like the output below.
# + TODO: print the description of each tag (see morphology example, below)
# + TODO: print the entities recognized by iterating over the Doc object (scrowl down after the morphology print to see an example outputs).

# %%
# TODO add your code here to print the tokens in the Doc object

for word in doc:
  print(word)
# Out:
# Washington
# University
# ,
# which
# is
# located
# in
# Missouri
# ,
# is
# named
# after
# George
# Washington
# .

# %% [markdown]
# + TODO: print the two entities containing "Washington"

# %%
# A slice of the Doc for "Washington University"
span = doc[0:2]

print(span)


# A slice of the Doc for "George Washington" (without the ".")

span2 = doc[-3:-1] #same as span2 = doc[12:14] 

print(span2)
# Out:
# Washington University
# George Washington

# %%
# TODO obtain number of sentences
print("The total of sentences is ", len(list(doc.sents)))
# Out:
# The total of sentences is  1

# %%
# morphology and syntax
for token in doc:
    # Get the token text, part-of-speech tag and dependency label
    token_text = token.text
    token_pos = token.pos_
    token_tag = token.tag_
    token_lemma = token.lemma_
    token_dep = token.dep_
    # This is for formatting only
    print(f"{token_text:<12}{token_pos:<10}{token_tag:<10}{token_lemma:<20}{token_dep:<20}")
# Out:
# Washington  PROPN     NNP       Washington          compound
# University  PROPN     NNP       University          nsubjpass
# ,           PUNCT     ,         ,                   punct
# which       PRON      WDT       which               nsubjpass
# is          AUX       VBZ       be                  auxpass
# located     VERB      VBN       locate              relcl
# in          ADP       IN        in                  prep
# Missouri    PROPN     NNP       Missouri            pobj
# ,           PUNCT     ,         ,                   punct
# is          AUX       VBZ       be                  auxpass
# named       VERB      VBN       name                ROOT
# after       ADP       IN        after               prep
# George      PROPN     NNP       George              compound
# Washington  PROPN     NNP       Washington          pobj
# .           PUNCT     .         .                   punct

# %%
# morphology and syntax
for token in doc:
    token_text = token.text
    token_pos = token.pos_
    token_tag = token.tag_
    token_lemma = token.lemma_
    token_dep = token.dep_
    # This is for formatting only
    # TODO modify the code above to print the description of each tag, like so:
    print(f"{token_text:<12}{token_pos:<10}{token_tag:<10}{token_lemma:<20}{token_dep:<20}")
# Out:
# Washington  PROPN     NNP       Washington          compound
# University  PROPN     NNP       University          nsubjpass
# ,           PUNCT     ,         ,                   punct
# which       PRON      WDT       which               nsubjpass
# is          AUX       VBZ       be                  auxpass
# located     VERB      VBN       locate              relcl
# in          ADP       IN        in                  prep
# Missouri    PROPN     NNP       Missouri            pobj
# ,           PUNCT     ,         ,                   punct
# is          AUX       VBZ       be                  auxpass
# named       VERB      VBN       name                ROOT
# after       ADP       IN        after               prep
# George      PROPN     NNP       George              compound
# Washington  PROPN     NNP       Washington          pobj
# .           PUNCT     .         .                   punct

# %%
# TODO Iterate over the predicted entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Washington University ORG
# Missouri GPE
# George Washington PERSON

# %%
# TODO modify the code above to iterate over the predicted entities at token level, like so:
# iob2 entities
import re

for token in doc:
    print (token.text, '---->', token.pos_, '---->', token.dep_, '---->', token.head.text)
# Out:
# Washington ----> PROPN ----> compound ----> University
# University ----> PROPN ----> nsubjpass ----> named
# , ----> PUNCT ----> punct ----> University
# which ----> PRON ----> nsubjpass ----> located
# is ----> AUX ----> auxpass ----> located
# located ----> VERB ----> relcl ----> University
# in ----> ADP ----> prep ----> located
# Missouri ----> PROPN ----> pobj ----> in
# , ----> PUNCT ----> punct ----> University
# is ----> AUX ----> auxpass ----> named
# named ----> VERB ----> ROOT ----> named
# after ----> ADP ----> prep ----> named
# George ----> PROPN ----> compound ----> Washington
# Washington ----> PROPN ----> pobj ----> after
# . ----> PUNCT ----> punct ----> named

# %%
# easy feature extraction
for token in doc:
  print (token, token.idx, token.text_with_ws, 
         token.is_alpha, token.is_punct, token.is_space,
         token.shape_, token.is_stop)
# Out:
# Washington 0 Washington  True False False Xxxxx False
# University 11 University True False False Xxxxx False
# , 21 ,  False True False , False
# which 23 which  True False False xxxx True
# is 29 is  True False False xx True
# located 32 located  True False False xxxx False
# in 40 in  True False False xx True
# Missouri 43 Missouri True False False Xxxxx False
# , 51 ,  False True False , False
# is 53 is  True False False xx True
# named 56 named  True False False xxxx False
# after 62 after  True False False xxxx True
# George 68 George  True False False Xxxxx False
# Washington 75 Washington True False False Xxxxx False
# . 85 . False True False . False

# %%
# stopwords available for English
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stopwords)
for stop_word in list(spacy_stopwords)[:10]:
  print(stop_word)
# Out:
# latter
# even
# such
# themselves
# throughout
# as
# if
# hence
# twelve
# what

# %% [markdown]
# # ASSIGNMENT 3
#
# + TODO: Remove stopwords from doc
# + TODO: print only the verbs, 3rd person singular present and the proper singular nouns

# %%
# TODO remove stopwords
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stopwords)
for stop_word in list(spacy_stopwords)[:10]:
  print(stop_word)
# Out:
# latter
# even
# such
# themselves
# throughout
# as
# if
# hence
# twelve
# what

# %%
# TODO print only verbs, 3rd person singular present and proper singular nouns
nouns = []
verbs = []

prop_n = "NNP"
aux = "VBZ"

for token in doc:
  if token.tag_ == prop_n:
    nouns.append(token)
  elif token.tag_ == aux:
    verbs.append(token)




print(nouns)
print(verbs)
# Out:
# [Washington, University, Missouri, George, Washington]
# [is, is]

# %% [markdown]
# # ASSIGNMENT 4 (BONUS 1)
#
# Visualizations with spacy. Check the documentation in  https://spacy.io/usage/visualizers and render the dependencies and NER annotations, like so:

# %%
from spacy.util import minify_html
from IPython.core.display import display, HTML
from spacy import displacy

options = {"compact": False, "bg": "black",
           "color": "yellow", "font": "Source Sans Pro", "distance": 110}

displacy.render(doc, style='ent', jupyter=True, options=options)
displacy.render(doc, style='dep', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Missouri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is named after
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="aed0930a86ae46539566b0da0e141225-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: yellow; background: black; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Washington</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">University,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">located</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">Missouri,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">named</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">George</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">Washington.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-1" stroke-width="2px" d="M180,222.0 C180,2.0 930.0,2.0 930.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-2" stroke-width="2px" d="M290,222.0 C290,112.0 480.0,112.0 480.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-3" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-4" stroke-width="2px" d="M180,222.0 C180,57.0 485.0,57.0 485.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M485.0,224.0 L493.0,212.0 477.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-5" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,224.0 L593.0,212.0 577.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-6" stroke-width="2px" d="M620,222.0 C620,167.0 695.0,167.0 695.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M695.0,224.0 L703.0,212.0 687.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-aed0930a86ae46539566b0da0e141225-0-7" stroke-width="2px" d="M840,222.0 C840,167.0 915.0,167.0 915.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-aed0930a86ae46539566b0da0e141225-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,224.0 L832,212.0 848,212.0" fill="currentColor"/>
# </g>
#
# <g class="displ

# %% [markdown]
# # ASSIGNMENT 5 (BONUS 2)
#
# In this task you will be annotating a movie review at document and sentence level.
#
# 1. Open the file '/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/resources/movie-review.txt'
# 2. Predict and print the various annotations seen previously (POS, NER, lemmas, etc.) for each of the sentences in the document using at least two language modules for one language of your interest (most basic and most advanced).
# 3. Visualize the results.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# TODO add code here
file_name = '/content/drive/MyDrive/2022-ILTAPP/resources/guardian.txt'

with open(file_name) as f:
  file_name = f.read()

doc = nlp(file_name)

print(file_name)
displacy.render(doc, style='ent', jupyter=True)

for token in doc:
  token_text = token.text
  token_pos = token.pos_
  token_tag = token.tag_
  token_lemma = token.lemma_
  token_dep = token.dep_
  print(f"{token_text:<12}{token_pos:<10}{token_tag:<10}{token_lemma:<20}{token_dep:<20}")
# Out:
# Twelve years after the fall of the Taliban, Afghanistan is heading for a near-record opium crop as instability pushes up the amount of land planted with illegal but lucrative poppies, according to a bleak UN report.
#
# The rapid growth of poppy farming as western troops head home reflects particularly badly on Britain, which was designated "lead nation" for counter-narcotics work over a decade ago.
#
# "Poppy cultivation is not only expected to expand in areas where it already existed in 2012 … but also in new areas or areas where poppy cultivation was stopped," the Afghanistan Opium Winter Risk Assessment found.
#
# The growth in opium cultivation reflects both spreading instability and concerns about the future. Farmers are more likely to plant the deadly crop in areas of high violence or where they have not received any agricultural aid, the report said.
#
# Opium traders are often happy to provide seeds, fertilisers and even advance payments to encourage crops, leaving farmers who do not have western or government agricultural help very vulnerable to their inducements.
#
# At the same time the more powerful figures in the drugs trade, from traffickers to corrupt government officials, who take over half the profit from each kilo of opium, have shrinking opportunities to earn money from Nato or international aid contracts – and may be preparing a war chest for upcoming presidential and parliamentary elections.
#
# "Opium cultivation is up for the third successive year, and production is heading towards record levels," said Jean-Luc Lemahieu, Afghanistan head of the UN Office on Drugs and Crime. "People are hedging against an insecure future both politically and economically."
#
# Just 14 of Afghanistan's 34 provinces are now "poppy free", down from 20 in 2010. In three provinces, the spring sowing was the first time this decade that farmers had risked an attempt at growing opium.
#
# The only figures showing a fall in cultivation, for western Herat province, may actually be due to a statistics blip. The UN was forced to use external data last year instead of the satellite images that are usually the basis of poppy growing calculations, and local officials protested heavily that the opium crop there had been overestimated.
#
# If this year's poppy fields are harvested without disruption, the country would likely regain its status as producer of 90% of the world's opium. Afghanistan's share of the deadly market slipped to around 75% after bad weather and a blight slashed production over the past two years.
#
# But the decline in opium production also drove up prices, to a record $300 a kilogramme. Prices have now slipped by over $100 but are still far above historic levels, helping tempt more farmers to turn land over to poppy.
#
# It seems unlikely that the poor harvests of the last year will be repeated; there have been no reports of blight and the exceptionally bitter winter of 2011-12 was followed this year by a milder one, creating expectations of a large crop.
#
# The increase has come despite a marked improvement in Afghanistan's specialised counter-narcotics units, Lemahieu said. Fear of eradication has become a far more significant reason for farmers to stick to legal crops than in the past, the report found.
#
# But overall the government and aid community has not prioritised efforts to cut back a crop and trade that feeds global markets for heroin, Lemahieu said, despite its corrosive effect on security, corruption and trust in Kabul.
#
# Typical of the official neglect are the 22 "national priority programmes" drawn up by Kabul to focus aid money and diplomatic efforts on its key development concerns including justice and education. Counter-narcotics was not one of them, nor has it been put at the heart of the other programmes.
#
# "We need to have counter-narcotics dealt with seriously by the entire government as well as the aid community," Lemahieu said. "One of the big missing links here is providing for the communities themselves."
#
# Eradication programmes that do not provide farmers with benefits such as healthcare and education, and support growing other crops will just push the Taliban or other insurgent groups that do tolerate or encourage poppy production, he added.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twelve years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taliban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Afghanistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is heading for a near-record opium crop as instability pushes up the amount of land planted with illegal but lucrative poppies, according to a bleak
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  report.</br></br>The rapid growth of poppy farming as western troops head home reflects particularly badly on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , which was designated &quot;lead nation&quot; for counter-narcotics work over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a decade ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>&quot;Poppy cultivation is not only expected to expand in areas where it already existed in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  … but also in new areas or areas where poppy cultivation was stopped,&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Afghanistan Opium Winter Risk Assessment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  found.</br></br>The growth in opium cultivation reflects both spreading instability and concerns about the future. Farmers are more likely to plant the deadly crop in areas of high violence or where they have not received any agricultural aid, the report said.</br></br>Opium traders are often happy to provide seeds, fertilisers and even advance payments to encourage crops, leaving farmers who do not have western or government agricultural help very vulnerable to their inducements.</br></br>At the same time the more powerful figures in the drugs trade, from traffickers to corrupt government officials, who take
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the profit from each kilo of opium, have shrinking opportunities to earn money from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or international aid contracts – and may be preparing a war chest for upcoming presidential and parliamentary elections.</br></br>&quot;Opium cultivation is up for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the third successive year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and production is heading towards record levels,&quot; said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jean-Luc Lemahieu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Afghanistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  head of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the UN Office on Drugs and Crime
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . &quot;People are hedging against an insecure future both politically and economically.&quot;</br></br>Just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Afghanistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  provinces are now &quot;poppy free&quot;, down from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  provinces, the spring sowing was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6e
# Twelve      NUM       CD        twelve              nummod
# years       NOUN      NNS       year                npadvmod
# after       ADP       IN        after               prep
# the         DET       DT        the                 det
# fall        NOUN      NN        fall                pobj
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# Taliban     PROPN     NNP       Taliban             pobj
# ,           PUNCT     ,         ,                   punct
# Afghanistan PROPN     NNP       Afghanistan         nsubj
# is          AUX       VBZ       be                  aux
# heading     VERB      VBG       head                ROOT
# for         ADP       IN        for                 prep
# a           DET       DT        a                   det
# near        ADJ       JJ        near                amod
# -           PUNCT     HYPH      -                   punct
# record      NOUN      NN        record              compound
# opium       NOUN      NN        opium               compound
# crop        NOUN      NN        crop                pobj
# as          SCONJ     IN        as                  mark
# instability NOUN      NN        instability         nsubj
# pushes      VERB      VBZ       push                advcl
# up          ADP       RP        up                  prt
# the         DET       DT        the                 det
# amount      NOUN      NN        amount              dobj
# of          ADP       IN        of                  prep
# land        NOUN      NN        land                pobj
# planted     VERB      VBN       plant               acl
# with        ADP       IN        with                prep
# illegal     ADJ       JJ        illegal             amod
# but         CCONJ     CC        but                 cc
# lucrative   ADJ       JJ        lucrative           conj
# poppies     NOUN      NNS       poppy               pobj
# ,           PUNCT     ,         ,                   punct
# according   VERB      VBG       accord              prep
# to          ADP       IN        to                  prep
# a           DET       DT        a                   det
# bleak       ADJ       JJ        bleak               amod
# UN          PROPN     NNP       UN                  compound
# report      NOUN      NN        report              pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# The         DET       DT        the                 det
# rapid       ADJ       JJ        rapid               amod
# growth      NOUN      NN        growth              nsubj
# of          ADP       IN        of                  prep
# poppy       ADJ       JJ        poppy               amod
# farming     NOUN      NN        farming             pobj
# as          SCONJ     IN        as                  mark
# western     ADJ       JJ        western             amod
# troops      NOUN      NNS       troop               nsubj
# head        VERB      VBP       head                advcl
# home        ADV       RB        home                advmod
# reflects    VERB      VBZ       reflect             ccomp
# particularlyADV       RB        particularly        advmod
# badly       ADV       RB        badly               advmod
# on          ADP       IN        on                  prep
# Britain     PROPN     NNP       Britain             pobj
# ,           PUNCT     ,         ,                   punct
# which       PRON      WDT       which               nsubjpass
# was         AUX       VBD       be                  auxpass
# designated  VERB      VBN       designate           relcl
# "           PUNCT     ``        "                   punct
# lead        NOUN      NN        lead                amod
# nation      NOUN      NN        nation              oprd
# "           PUNCT     ''        "                   punct
# for         ADP       IN        for                 prep
# counter     ADJ       JJ        counter             amod
# -           ADJ       JJ        -                   amod
# narcotics   ADJ       JJ        narcotics           amod
# work        NOUN      NN        work                pobj
# over        ADP       IN        over                prep
# a           DET       DT        a                   det
# decade      NOUN      NN        decade              npadvmod
# ago         ADV       RB        ago                 advmod
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# "           PUNCT     ``        "                   punct
# Poppy       ADJ       JJ        poppy               amod
# cultivation NOUN      NN        cultivation         nsubjpass
# is          AUX       VBZ       be                  auxpass
# not         PART      RB        not                 preconj
# only        ADV       RB        only                advmod
# expected    VERB      VBN       expect              ccomp
# to          PART      TO        to                  aux
# expand      VERB      VB        expand              xcomp
# in          ADP       IN        in                  prep
# areas       NOUN      NNS       area                pobj
# where       SCONJ     WRB       where               advmod
# it          PRON      PRP       it                  nsubj
# already     ADV       RB        already             advmod
# existed     VERB      VBD       exist               relcl
# in          ADP       IN        in                  prep
# 2012        NUM       CD        2012                pobj
# …           PUNCT     ,         …                   punct
# but         CCONJ     CC        but                 cc
# also        ADV       RB        also                advmod
# in          ADP       IN        in                  prep
# new         ADJ       JJ        new                 amod
# areas       NOUN      NNS       area                pobj
# or          CCONJ     CC        or                  cc
# areas       NOUN      NNS       area                conj
# where       SCONJ     WRB       where               advmod
# poppy       ADJ       JJ        poppy               amod
# cultivation NOUN      NN        cultivation         nsubjpass
# was         AUX       VBD       be                  auxpass
# stopped     VERB      VBN       stop                relcl
# ,           PUNCT     ,         ,                   punct
# "           PUNCT     ''        "                   punct
# the         DET       DT        the                 det
# Afghanistan PROPN     NNP       Afghanistan         compound
# Opium       PROPN     NNP       Opium               compound
# Winter      PROPN     NNP       Winter              compound
# Risk        PROPN     NNP       Risk                compound
# Assessment  PROPN     NNP       Assessment          nsubj
# found       VERB      VBD       find                ROOT
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# The         DET       DT        the                 det
# growth      NOUN      NN        growth              nsubj
# in          ADP       IN        in                  prep
# opium       NOUN      NN        opium               compound
# cultivation NOUN      NN        cultivation         pobj
# reflects    VERB      VBZ       reflect             ROOT
# both        PRON      DT        both                preconj
# spreading   VERB      VBG       spread              ccomp
# instability NOUN      NN        instability         dobj
# and         CCONJ     CC        and                 cc
# concerns    NOUN      NNS       concern             conj
# about       ADP       IN        about               prep
# the         DET       DT        the                 det
# future      NOUN      NN        future              pobj
# .           PUNCT     .         .                   punct
# Farmers     NOUN      NNS       farmer              nsubj
# are         AUX       VBP       be                  ccomp
# more        ADV       RBR       more                advmod
# likely      ADJ       JJ        likely              acomp
# to          PART      TO        to                  aux
# plant       VERB      VB        plant               xcomp
# the         DET       DT        the                 det
# deadly      ADJ       JJ        deadly              amod
# crop        NOUN      NN        crop                dobj
# in          ADP       IN        in                  prep
# areas       NOUN      NNS       area                pobj
# of          ADP       IN        of                  prep
# high        ADJ       JJ        high                amod
# violence    NOUN      NN        violence            pobj
# or          CCONJ     CC        or                  cc
# where       SCONJ     WRB       where               advmod
# they        PRON      PRP       they                nsubj
# have        AUX       VBP       have                aux
# not         PART      RB        not                 neg
# received    VERB      VBN       receive             conj
# any         DET       DT        any                 det
# agriculturalADJ       JJ        agricultural        amod
# aid         NOUN      NN        aid                 dobj
# ,           PUNCT     ,         ,                   punct
# the         DET       DT        the                 det
# report      NOUN      NN        report              nsubj
# said        VERB      VBD       say                 ROOT
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# Opium       NOUN      NN        opium               compound
# traders     NOUN      NNS       trader              nsubj
# are         AUX       VBP       be                  ROOT
# often       ADV       RB        often               advmod
# happy       ADJ       JJ        happy               acomp
# to          PART      TO        to                  aux
# provide     VERB      VB        provide             xcomp
# seeds       NOUN      NNS       seed                dobj
# ,           PUNCT     ,         ,                   punct
# fertilisers NOUN      NNS       fertiliser          conj
# and         CCONJ     CC        and                 cc
# even        ADV       RB        even                advmod
# advance     NOUN      NN        advance             compound
# payments    NOUN      NNS       payment             conj
# to          PART      TO        to                  aux
# encourage   VERB      VB        encourage           advcl
# crops       NOUN      NNS       crop                dobj
# ,           PUNCT     ,         ,                   punct
# leaving     VERB      VBG       leave               advcl
# farmers     NOUN      NNS       farmer              dobj
# who         PRON      WP        who                 nsubj
# do          AUX       VBP       do                  aux
# not         PART      RB        not                 neg
# have        VERB      VB        have                relcl
# western     ADJ       JJ        western             amod
# or          CCONJ     CC        or                  cc
# government  NOUN      NN        government          conj
# agriculturalADJ       JJ        agricultural        amod
# help        NOUN      NN        help                dobj
# very        ADV       RB        very                advmod
# vulnerable  ADJ       JJ        vulnerable          amod
# to          ADP       IN        to                  prep
# their       PRON      PRP$      their               poss
# inducements NOUN      NNS       inducement          pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# At          ADP       IN        at                  prep
# the         DET       DT        the                 det
# same        ADJ       JJ        same                amod
# time        NOUN      NN        time                pobj
# the         DET       DT        the                 det
# more        ADV       RBR       more                advmod
# powerful    ADJ       JJ        powerful            amod
# figures     NOUN      NNS       figure              pobj
# in          ADP       IN        in                  prep
# the         DET       DT        the                 det
# drugs       NOUN      NNS       drug                compound
# trade       NOUN      NN        trade               pobj
# ,           PUNCT     ,         ,                   punct
# from        ADP       IN        from                prep
# traffickers NOUN      NNS       trafficker          pobj
# to          ADP       IN        to                  prep
# corrupt     ADJ       JJ        corrupt             amod
# government  NOUN      NN        government          compound
# officials   NOUN      NNS       official            pobj
# ,           PUNCT     ,         ,                   punct
# who         PRON      WP        who                 nsubj
# take        VERB      VBP       take                relcl
# over        ADP       IN        over                quantmod
# half        DET       PDT       half                nummod
# the         DET       DT        the                 det
# profit      NOUN      NN        profit              dobj
# from        ADP       IN        from                prep
# each        DET       DT        each                det
# kilo        NOUN      NN        kilo                pobj
# of          ADP       IN        of                  prep
# opium       NOUN      NN        opium               pobj
# ,           PUNCT     ,         ,                   punct
# have        AUX       VBP       have                aux
# shrinking   VERB      VBG       shrink              ROOT
# opportunitiesNOUN      NNS       opportunity         dobj
# to          PART      TO        to                  aux
# earn        VERB      VB        earn                acl
# money       NOUN      NN        money               dobj
# from        ADP       IN        from                prep
# Nato        PROPN     NNP       Nato                pobj
# or          CCONJ     CC        or                  cc
# internationalADJ       JJ        international       amod
# aid         NOUN      NN        aid                 compound
# contracts   NOUN      NNS       contract            conj
# –           PUNCT     :         –                   punct
# and         CCONJ     CC        and                 cc
# may         AUX       MD        may                 aux
# be          AUX       VB        be                  aux
# preparing   VERB      VBG       prepare             conj
# a           DET       DT        a                   det
# war         NOUN      NN        war                 compound
# chest       NOUN      NN        chest               dobj
# for         ADP       IN        for                 prep
# upcoming    ADJ       JJ        upcoming            amod
# presidentialADJ       JJ        presidential        amod
# and         CCONJ     CC        and                 cc
# parliamentaryADJ       JJ        parliamentary       conj
# elections   NOUN      NNS       election            pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# "           PUNCT     ``        "                   punct
# Opium       NOUN      NN        opium               compound
# cultivation NOUN      NN        cultivation         nsubj
# is          AUX       VBZ       be                  ccomp
# up          ADV       RB        up                  advmod
# for         ADP       IN        for                 prep
# the         DET       DT        the                 det
# third       ADJ       JJ        third               amod
# successive  ADJ       JJ        successive          amod
# year        NOUN      NN        year                pobj
# ,           PUNCT     ,         ,                   punct
# and         CCONJ     CC        and                 cc
# production  NOUN      NN        production          nsubj
# is          AUX       VBZ       be                  aux
# heading     VERB      VBG       head                conj
# towards     ADP       IN        towards             prep
# record      NOUN      NN        record              compound
# levels      NOUN      NNS       level               pobj
# ,           PUNCT     ,         ,                   punct
# "           PUNCT     ''        "                   punct
# said        VERB      VBD       say                 ROOT
# Jean        PROPN     NNP       Jean                compound
# -           PUNCT     HYPH      -                   punct
# Luc         PROPN     NNP       Luc                 compound
# Lemahieu    PROPN     NNP       Lemahieu            nsubj
# ,           PUNCT     ,         ,                   punct
# Afghanistan PROPN     NNP       Afghanistan         compound
# head        NOUN      NN        head                appos
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# UN          PROPN     NNP       UN                  compound
# Office      PROPN     NNP       Office              pobj
# on          ADP       IN        on                  prep
# Drugs       NOUN      NNS       drug                pobj
# and         CCONJ     CC        and                 cc
# Crime       PROPN     NNP       Crime               conj
# .           PUNCT     .         .                   punct
# "           PUNCT     ``        "                   punct
# People      NOUN      NNS       People              nsubj
# are         AUX       VBP       be                  aux
# hedging     VERB      VBG       hedge               ROOT
# against     ADP       IN        against             prep
# an          DET       DT        an                  det
# insecure    NOUN      NN        insecure            amod
# future      NOUN      NN        future              pobj
# both        PRON      DT        both                preconj
# politically ADV       RB        politically         advmod
# and         CCONJ     CC        and                 cc
# economicallyADV       RB        economically        conj
# .           PUNCT     .         .                   punct
# "           PUNCT     ``        "                   punct
#
#
#           SPACE     _SP
#
#                   dep
# Just        ADV       RB        just                advmod
# 14          NUM       CD        14                  nsubj
# of          ADP       IN        of                  prep
# Afghanistan PROPN     NNP       Afghanistan         poss
# 's          PART      POS       's                  case
# 34          NUM       CD        34                  nummod
# provinces   NOUN      NNS       province            pobj
# are         AUX       VBP       be                  ROOT
# now         ADV       RB        now                 advmod
# "           PUNCT     ``        "                   punct
# poppy       ADJ       JJ        poppy               advmod
# free        ADJ       JJ        free                acomp
# "           PUNCT     ''        "                   punct
# ,           PUNCT     ,         ,                   punct
# down        ADV       RB        down                advmod
# from        ADP       IN        from                prep
# 20          NUM       CD        20                  pobj
# in          ADP       IN        in                  prep
# 2010        NUM       CD        2010                pobj
# .           PUNCT     .         .                   punct
# In          ADP       IN        in                  prep
# three       NUM       CD        three               nummod
# provinces   NOUN      NNS       province            pobj
# ,           PUNCT     ,         ,                   punct
# the         DET       DT        the                 det
# spring      NOUN      NN        spring              compound
# sowing      NOUN      NN        sowing              nsubj
# was         AUX       VBD       be                  ROOT
# the         DET       DT        the                 det
# first       ADJ       JJ        first               amod
# time        NOUN      NN        time                attr
# this        DET       DT        this                det
# decade      NOUN      NN        decade              npadvmod
# that        SCONJ     IN        that                mark
# farmers     NOUN      NNS       farmer              nsubj
# had         AUX       VBD       have                aux
# risked      VERB      VBN       risk                relcl
# an          DET       DT        an                  det
# attempt     NOUN      NN        attempt             dobj
# at          ADP       IN        at                  prep
# growing     VERB      VBG       grow                amod
# opium       NOUN      NN        opium               pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# The         DET       DT        the                 det
# only        ADJ       JJ        only                amod
# figures     NOUN      NNS       figure              nsubj
# showing     VERB      VBG       show                acl
# a           DET       DT        a                   det
# fall        NOUN      NN        fall                dobj
# in          ADP       IN        in                  prep
# cultivation NOUN      NN        cultivation         pobj
# ,           PUNCT     ,         ,                   punct
# for         ADP       IN        for                 prep
# western     ADJ       JJ        western             amod
# Herat       PROPN     NNP       Herat               compound
# province    NOUN      NN        province            pobj
# ,           PUNCT     ,         ,                   punct
# may         AUX       MD        may                 aux
# actually    ADV       RB        actually            advmod
# be          AUX       VB        be                  ROOT
# due         ADJ       JJ        due                 acomp
# to          ADP       IN        to                  prep
# a           DET       DT        a                   det
# statistics  NOUN      NNS       statistic           compound
# blip        NOUN      NN        blip                pobj
# .           PUNCT     .         .                   punct
# The         DET       DT        the                 det
# UN          PROPN     NNP       UN                  nsubjpass
# was         AUX       VBD       be                  auxpass
# forced      VERB      VBN       force               ROOT
# to          PART      TO        to                  aux
# use         VERB      VB        use                 xcomp
# external    ADJ       JJ        external            amod
# data        NOUN      NNS       datum               dobj
# last        ADJ       JJ        last                amod
# year        NOUN      NN        year                npadvmod
# instead     ADV       RB        instead             advmod
# of          ADP       IN        of                  cc
# the         DET       DT        the                 det
# satellite   NOUN      NN        satellite           compound
# images      NOUN      NNS       image               pobj
# that        PRON      WDT       that                nsubj
# are         AUX       VBP       be                  relcl
# usually     ADV       RB        usually             advmod
# the         DET       DT        the                 det
# basis       NOUN      NN        basis               attr
# of          ADP       IN        of                  prep
# poppy       ADJ       JJ        poppy               amod
# growing     VERB      VBG       grow                amod
# calculationsNOUN      NNS       calculation         pobj
# ,           PUNCT     ,         ,                   punct
# and         CCONJ     CC        and                 cc
# local       ADJ       JJ        local               amod
# officials   NOUN      NNS       official            nsubj
# protested   VERB      VBD       protest             conj
# heavily     ADV       RB        heavily             advmod
# that        SCONJ     IN        that                mark
# the         DET       DT        the                 det
# opium       NOUN      NN        opium               compound
# crop        NOUN      NN        crop                nsubjpass
# there       PRON      EX        there               advmod
# had         AUX       VBD       have                aux
# been        AUX       VBN       be                  auxpass
# overestimatedVERB      VBN       overestimate        ccomp
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# If          SCONJ     IN        if                  mark
# this        DET       DT        this                det
# year        NOUN      NN        year                poss
# 's          PART      POS       's                  case
# poppy       ADJ       JJ        poppy               amod
# fields      NOUN      NNS       field               nsubjpass
# are         AUX       VBP       be                  auxpass
# harvested   VERB      VBN       harvest             advcl
# without     ADP       IN        without             prep
# disruption  NOUN      NN        disruption          pobj
# ,           PUNCT     ,         ,                   punct
# the         DET       DT        the                 det
# country     NOUN      NN        country             nsubj
# would       AUX       MD        would               aux
# likely      ADV       RB        likely              advmod
# regain      VERB      VB        regain              ROOT
# its         PRON      PRP$      its                 poss
# status      NOUN      NN        status              dobj
# as          ADP       IN        as                  prep
# producer    NOUN      NN        producer            pobj
# of          ADP       IN        of                  prep
# 90          NUM       CD        90                  nummod
# %           NOUN      NN        %                   pobj
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# world       NOUN      NN        world               poss
# 's          PART      POS       's                  case
# opium       NOUN      NN        opium               pobj
# .           PUNCT     .         .                   punct
# Afghanistan PROPN     NNP       Afghanistan         poss
# 's          PART      POS       's                  case
# share       NOUN      NN        share               nsubj
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# deadly      ADJ       JJ        deadly              amod
# market      NOUN      NN        market              pobj
# slipped     VERB      VBD       slip                ROOT
# to          ADP       IN        to                  prep
# around      ADP       IN        around              quantmod
# 75          NUM       CD        75                  nummod
# %           NOUN      NN        %                   pobj
# after       ADP       IN        after               prep
# bad         ADJ       JJ        bad                 amod
# weather     NOUN      NN        weather             pobj
# and         CCONJ     CC        and                 cc
# a           DET       DT        a                   det
# blight      NOUN      NN        blight              npadvmod
# slashed     VERB      VBD       slash               amod
# production  NOUN      NN        production          conj
# over        ADP       IN        over                prep
# the         DET       DT        the                 det
# past        ADJ       JJ        past                amod
# two         NUM       CD        two                 nummod
# years       NOUN      NNS       year                pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# But         CCONJ     CC        but                 cc
# the         DET       DT        the                 det
# decline     NOUN      NN        decline             nsubj
# in          ADP       IN        in                  prep
# opium       NOUN      NN        opium               compound
# production  NOUN      NN        production          pobj
# also        ADV       RB        also                advmod
# drove       VERB      VBD       drive               ROOT
# up          ADP       RP        up                  prt
# prices      NOUN      NNS       price               dobj
# ,           PUNCT     ,         ,                   punct
# to          ADP       IN        to                  prep
# a           DET       DT        a                   det
# record      NOUN      NN        record              pobj
# $           SYM       $         $                   nmod
# 300         NUM       CD        300                 appos
# a           DET       DT        a                   det
# ...
# specialised ADJ       JJ        specialised         amod
# counter     NOUN      NN        counter             amod
# -           ADJ       JJ        -                   amod
# narcotics   ADJ       JJ        narcotics           amod
# units       NOUN      NNS       unit                pobj
# ,           PUNCT     ,         ,                   punct
# Lemahieu    PROPN     NNP       Lemahieu            nsubj
# said        VERB      VBD       say                 ROOT
# .           PUNCT     .         .                   punct
# Fear        NOUN      NN        fear                nsubj
# of          ADP       IN        of                  prep
# eradication NOUN      NN        eradication         pobj
# has         AUX       VBZ       have                aux
# become      VERB      VBN       become              ccomp
# a           DET       DT        a                   det
# far         ADV       RB        far                 advmod
# more        ADV       RBR       more                advmod
# significant ADJ       JJ        significant         amod
# reason      NOUN      NN        reason              attr
# for         SCONJ     IN        for                 mark
# farmers     NOUN      NNS       farmer              nsubj
# to          PART      TO        to                  aux
# stick       VERB      VB        stick               relcl
# to          ADP       IN        to                  prep
# legal       ADJ       JJ        legal               amod
# crops       NOUN      NNS       crop                pobj
# than        ADP       IN        than                prep
# in          ADP       IN        in                  prep
# the         DET       DT        the                 det
# past        NOUN      NN        past                pobj
# ,           PUNCT     ,         ,                   punct
# the         DET       DT        the                 det
# report      NOUN      NN        report              nsubj
# found       VERB      VBD       find                ROOT
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# But         CCONJ     CC        but                 punct
# overall     ADV       RB        overall             advmod
# the         DET       DT        the                 det
# government  NOUN      NN        government          nmod
# and         CCONJ     CC        and                 cc
# aid         NOUN      NN        aid                 conj
# community   NOUN      NN        community           nsubj
# has         AUX       VBZ       have                aux
# not         PART      RB        not                 neg
# prioritised VERB      VBN       prioritise          ccomp
# efforts     NOUN      NNS       effort              dobj
# to          PART      TO        to                  aux
# cut         VERB      VB        cut                 acl
# back        ADP       RP        back                prt
# a           DET       DT        a                   det
# crop        NOUN      NN        crop                dobj
# and         CCONJ     CC        and                 cc
# trade       NOUN      NN        trade               conj
# that        PRON      WDT       that                nsubj
# feeds       VERB      VBZ       feed                relcl
# global      ADJ       JJ        global              amod
# markets     NOUN      NNS       market              dobj
# for         ADP       IN        for                 prep
# heroin      NOUN      NN        heroin              pobj
# ,           PUNCT     ,         ,                   punct
# Lemahieu    PROPN     NNP       Lemahieu            nsubj
# said        VERB      VBD       say                 ROOT
# ,           PUNCT     ,         ,                   punct
# despite     SCONJ     IN        despite             prep
# its         PRON      PRP$      its                 poss
# corrosive   ADJ       JJ        corrosive           amod
# effect      NOUN      NN        effect              pobj
# on          ADP       IN        on                  prep
# security    NOUN      NN        security            pobj
# ,           PUNCT     ,         ,                   punct
# corruption  NOUN      NN        corruption          conj
# and         CCONJ     CC        and                 cc
# trust       NOUN      NN        trust               conj
# in          ADP       IN        in                  prep
# Kabul       PROPN     NNP       Kabul               pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# Typical     ADJ       JJ        typical             amod
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# official    ADJ       JJ        official            amod
# neglect     NOUN      NN        neglect             pobj
# are         AUX       VBP       be                  ROOT
# the         DET       DT        the                 det
# 22          NUM       CD        22                  nummod
# "           PUNCT     ``        "                   punct
# national    ADJ       JJ        national            amod
# priority    NOUN      NN        priority            compound
# programmes  NOUN      NNS       programme           attr
# "           PUNCT     ''        "                   punct
# drawn       VERB      VBN       draw                acl
# up          ADP       RP        up                  prt
# by          ADP       IN        by                  agent
# Kabul       PROPN     NNP       Kabul               pobj
# to          PART      TO        to                  aux
# focus       VERB      VB        focus               advcl
# aid         NOUN      NN        aid                 compound
# money       NOUN      NN        money               dobj
# and         CCONJ     CC        and                 cc
# diplomatic  ADJ       JJ        diplomatic          amod
# efforts     NOUN      NNS       effort              conj
# on          ADP       IN        on                  prep
# its         PRON      PRP$      its                 poss
# key         ADJ       JJ        key                 amod
# development NOUN      NN        development         compound
# concerns    NOUN      NNS       concern             pobj
# including   VERB      VBG       include             prep
# justice     NOUN      NN        justice             pobj
# and         CCONJ     CC        and                 cc
# education   NOUN      NN        education           conj
# .           PUNCT     .         .                   punct
# Counter     NOUN      NN        counter             compound
# -           PROPN     NNP       -                   punct
# narcotics   PROPN     NNP       narcotics           nsubj
# was         AUX       VBD       be                  ROOT
# not         PART      RB        not                 neg
# one         NUM       CD        one                 attr
# of          ADP       IN        of                  prep
# them        PRON      PRP       they                pobj
# ,           PUNCT     ,         ,                   punct
# nor         CCONJ     CC        nor                 cc
# has         AUX       VBZ       have                aux
# it          PRON      PRP       it                  nsubjpass
# been        AUX       VBN       be                  auxpass
# put         VERB      VBN       put                 conj
# at          ADP       IN        at                  prep
# the         DET       DT        the                 det
# heart       NOUN      NN        heart               pobj
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# other       ADJ       JJ        other               amod
# programmes  NOUN      NNS       programme           pobj
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
# "           PUNCT     ``        "                   punct
# We          PRON      PRP       we                  nsubj
# need        VERB      VBP       need                ccomp
# to          PART      TO        to                  aux
# have        VERB      VB        have                xcomp
# counter     NOUN      NN        counter             dobj
# -           ADJ       JJ        -                   dobj
# narcotics   NOUN      NNS       narcotic            nsubj
# dealt       VERB      VBD       deal                ccomp
# with        ADP       IN        with                prep
# seriously   ADV       RB        seriously           pcomp
# by          ADP       IN        by                  agent
# the         DET       DT        the                 det
# entire      ADJ       JJ        entire              amod
# government  NOUN      NN        government          pobj
# as          ADV       RB        as                  advmod
# well        ADV       RB        well                advmod
# as          ADP       IN        as                  cc
# the         DET       DT        the                 det
# aid         NOUN      NN        aid                 compound
# community   NOUN      NN        community           conj
# ,           PUNCT     ,         ,                   punct
# "           PUNCT     ''        "                   punct
# Lemahieu    PROPN     NNP       Lemahieu            nsubj
# said        VERB      VBD       say                 ROOT
# .           PUNCT     .         .                   punct
# "           PUNCT     ``        "                   punct
# One         NUM       CD        one                 nsubj
# of          ADP       IN        of                  prep
# the         DET       DT        the                 det
# big         ADJ       JJ        big                 amod
# missing     VERB      VBG       miss                amod
# links       NOUN      NNS       link                pobj
# here        ADV       RB        here                advmod
# is          AUX       VBZ       be                  aux
# providing   VERB      VBG       provide             ROOT
# for         ADP       IN        for                 prep
# the         DET       DT        the                 det
# communities NOUN      NNS       community           pobj
# themselves  PRON      PRP       themselves          appos
# .           PUNCT     .         .                   punct
# "           PUNCT     ``        "                   punct
#
#
#           SPACE     _SP
#
#                   dep
# Eradication NOUN      NN        eradication         compound
# programmes  NOUN      NNS       programme           nsubj
# that        PRON      WDT       that                nsubj
# do          AUX       VBP       do                  aux
# not         PART      RB        not                 neg
# provide     VERB      VB        provide             relcl
# farmers     NOUN      NNS       farmer              dobj
# with        ADP       IN        with                prep
# benefits    NOUN      NNS       benefit             pobj
# such        ADJ       JJ        such                amod
# as          ADP       IN        as                  prep
# healthcare  NOUN      NN        healthcare          pobj
# and         CCONJ     CC        and                 cc
# education   NOUN      NN        education           conj
# ,           PUNCT     ,         ,                   punct
# and         CCONJ     CC        and                 cc
# support     VERB      VB        support             conj
# growing     VERB      VBG       grow                amod
# other       ADJ       JJ        other               amod
# crops       NOUN      NNS       crop                dobj
# will        AUX       MD        will                aux
# just        ADV       RB        just                advmod
# push        VERB      VB        push                ccomp
# the         DET       DT        the                 det
# Taliban     PROPN     NNP       Taliban             dobj
# or          CCONJ     CC        or                  cc
# other       ADJ       JJ        other               amod
# insurgent   NOUN      NN        insurgent           compound
# groups      NOUN      NNS       group               conj
# that        PRON      WDT       that                nsubj
# do          AUX       VBP       do                  aux
# tolerate    VERB      VB        tolerate            relcl
# or          CCONJ     CC        or                  cc
# encourage   VERB      VB        encourage           conj
# poppy       ADJ       JJ        poppy               amod
# production  NOUN      NN        production          dobj
# ,           PUNCT     ,         ,                   punct
# he          PRON      PRP       he                  nsubj
# added       VERB      VBD       add                 ROOT
# .           PUNCT     .         .                   punct
#
#
#           SPACE     _SP
#
#                   dep
